# %%
import requests
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %%
import pandas as pd

dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame
# Out:
#                            sna  tot  sbi   sarea                 mday
# 0           YouBike2.0_捷運科技大樓站   28    3     大安區  2023-05-27 13:48:14  \
# 1       YouBike2.0_復興南路二段273號前   21    0     大安區  2023-05-27 13:47:04
# 2         YouBike2.0_國北教大實小東側門   16    0     大安區  2023-05-27 13:46:04
# 3            YouBike2.0_和平公園東側   11    3     大安區  2023-05-27 13:43:14
# 4         YouBike2.0_辛亥復興路口西北側   16    1     大安區  2023-05-27 13:40:21
# ...                        ...  ...  ...     ...                  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   18    臺大專區  2023-05-27 13:40:21
# 1276        YouBike2.0_臺大黑森林西側   20    8    臺大專區  2023-05-27 13:48:15
# 1277        YouBike2.0_臺大獸醫館南側   24   12    臺大專區  2023-05-27 13:48:15
# 1278      YouBike2.0_臺大新體育館東南側   40    5    臺大專區  2023-05-27 13:44:17
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    2  臺大公館校區  2023-05-27 13:39:14
#
#                  ar  bemp act
# 0       復興南路二段235號前    22   1
# 1      復興南路二段273號西側    21   1
# 2       和平東路二段96巷7號    15   1
# 3     和平東路二段118巷33號     8   1
# 4        復興南路二段368號    15   1
# ...             ...   ...  ..
# 1275       臺大圖書館西南側    12   1
# 1276        臺大霖澤館南側    11   1
# 1277       臺大獸醫系館南側    12   1
# 1278        臺大體育館東側    35   1
# 1279       明達館北側前空地    15   1
#
# [1280 rows x 8 columns]

# %%
#選取欄位
dataFrame[['sna', 'tot', 'sbi']]
# Out:
#                            sna  tot  sbi
# 0           YouBike2.0_捷運科技大樓站   28    3
# 1       YouBike2.0_復興南路二段273號前   21    0
# 2         YouBike2.0_國北教大實小東側門   16    0
# 3            YouBike2.0_和平公園東側   11    3
# 4         YouBike2.0_辛亥復興路口西北側   16    1
# ...                        ...  ...  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   18
# 1276        YouBike2.0_臺大黑森林西側   20    8
# 1277        YouBike2.0_臺大獸醫館南側   24   12
# 1278      YouBike2.0_臺大新體育館東南側   40    5
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    2
#
# [1280 rows x 3 columns]

# %%
#選取列(slice)
dataFrame[67:72]
# Out:
#                            sna  tot  sbi sarea                 mday
# 67    YouBike2.0_敦化南路二段293巷口南側   14    4   大安區  2023-05-27 13:31:15  \
# 68           YouBike2.0_敦化基隆路口   29    3   大安區  2023-05-27 13:47:14
# 69       YouBike2.0_安和路二段181巷口   17    1   大安區  2023-05-27 13:25:15
# 70  YouBike2.0_臨江街夜市(通化街101巷口)   30    2   大安區  2023-05-27 13:48:14
# 71       YouBike2.0_臨江街夜市(基隆路)   17    3   大安區  2023-05-27 13:43:14
#
#                ar  bemp act
# 67  敦化南路二段293巷口南側    10   1
# 68     敦化南路二段218號    24   1
# 69      安和路二段185號    16   1
# 70        通化街111號    27   1
# 71      基隆路二段108號    11   1

# %%
#同時選取欄例
#loc[index,column],iloc[index,column]
dataFrame.loc[100:120,['sna','sarea']]
# Out:
#                             sna sarea
# 100  YouBike2.0_捷運大安森林公園站(5號出口)   大安區
# 101           YouBike2.0_信義建國路口   大安區
# 102             YouBike2.0_東豐公園   大安區
# 103     YouBike2.0_德安公園(四維路66巷)   大安區
# 104    YouBike2.0_捷運忠孝復興站(5號出口)   大安區
# 105    YouBike2.0_捷運忠孝敦化站(2號出口)   大安區
# 106    YouBike2.0_捷運忠孝敦化站(7號出口)   大安區
# 107          YouBike2.0_瑞安街208巷   大安區
# 108          YouBike2.0_樂利路21巷口   大安區
# 109  YouBike2.0_捷運科技大樓站(台北教育大學)   大安區
# 110   YouBike2.0_捷運國父紀念館站(2號出口)   大安區
# 111             YouBike2.0_仁愛醫院   大安區
# 112    YouBike2.0_捷運信義安和站(4號出口)   大安區
# 113             YouBike2.0_成功國宅   大安區
# 114           YouBike2.0_仁愛延吉街口   大安區
# 115    YouBike2.0_捷運信義安和站(1號出口)   大安區
# 116      YouBike2.0_敦化南路二段103巷口   大安區
# 117      YouBike2.0_復興南路二段128巷口   大安區
# 118         YouBike2.0_和平東建國南路口   大安區
# 119             YouBike2.0_芳蘭山莊   大安區
# 120      YouBike2.0_復興南路一段126巷口   大安區

# %%
dataFrame.iloc[100:120,[0,3]]
# Out:
#                             sna sarea
# 100  YouBike2.0_捷運大安森林公園站(5號出口)   大安區
# 101           YouBike2.0_信義建國路口   大安區
# 102             YouBike2.0_東豐公園   大安區
# 103     YouBike2.0_德安公園(四維路66巷)   大安區
# 104    YouBike2.0_捷運忠孝復興站(5號出口)   大安區
# 105    YouBike2.0_捷運忠孝敦化站(2號出口)   大安區
# 106    YouBike2.0_捷運忠孝敦化站(7號出口)   大安區
# 107          YouBike2.0_瑞安街208巷   大安區
# 108          YouBike2.0_樂利路21巷口   大安區
# 109  YouBike2.0_捷運科技大樓站(台北教育大學)   大安區
# 110   YouBike2.0_捷運國父紀念館站(2號出口)   大安區
# 111             YouBike2.0_仁愛醫院   大安區
# 112    YouBike2.0_捷運信義安和站(4號出口)   大安區
# 113             YouBike2.0_成功國宅   大安區
# 114           YouBike2.0_仁愛延吉街口   大安區
# 115    YouBike2.0_捷運信義安和站(1號出口)   大安區
# 116      YouBike2.0_敦化南路二段103巷口   大安區
# 117      YouBike2.0_復興南路二段128巷口   大安區
# 118         YouBike2.0_和平東建國南路口   大安區
# 119             YouBike2.0_芳蘭山莊   大安區

# %%
#搜尋欄位值內的資料
#1先抓出Series

#bool Series
min=int(input("請輸入要查詢的可借數量:"))
mask = dataFrame['sbi'] <= min
mask_dataFrame = dataFrame[mask]
mask_dataFrame.to_csv('可借小於3的站點.csv')
filename = f'可借小於{min}的站點.xlsx'
mask_dataFrame.to_excel(filename)
# Out:
# Bad pipe message: %s [b',\xe8\x84\xd0rJ6v\rka\xb8\xbf\x0f\xd9\x06>\xe4 #\xd5\x1b\n\\fW\xc0\x9f\xd50GxR\xf9\xff^\xe7\xb7\x85\x10\x94\x02#\x107\xf6t\x8b\x82A\xdd\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \xca3\x0b\xf9K\xe0\xc2\\=\xbc=']
# Bad pipe message: %s [b"\xebVv\xc4\x97\xf4\xa8\xf5Q\xb7tS\xe5\xac(\xc368\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00"]
# Bad pipe message: %s [b'\xab\x87\xc8\x8dS\xccy0-;\xf1\x10};^(G3\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0']
# Bad pipe message: %s [b'\xc9M\xa7X\x8a\x82\x99U\xca\xb5\x92\xaa\x0f\xd8H\t<\xfb\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00']
# Bad pipe message: %s [b'\xd1w\xe1eqA\xdd(\rNL\xf8\x90\x98p\xbdE\x08\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00']
# Bad pipe message: %s [b"S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0"]
# Bad pipe message: %s [b'\x0c\x00\x00\t127.0.0.1']
# Bad pipe message: %s [b'\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00']
# Bad pipe message: %s [b'\x11\xc0\x08\xc0\x12\x00']
# Bad pipe message: %s [b'\x17\x00\x03\xc0\x10']
# Bad pipe message: %s [b'\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0']
# Bad pipe message: %s [b'U\xb4\x88\xdc\xdf/M!`\x15\r\xca4=\xcf%\x1b\xfc\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99']
# Bad pipe message: %s [b"\xe7/ytd\xfbr\x9f\x94,\x86\xc6\x14\x1al\x9f\xf5l\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\r\x00 \x00"]
# Bad pipe message: %s [b'\x01\x06\x02\x06\x03\x05\x01\x05\x02\x05\x03\x04\x01\x04\x02\x04\x03\x03\x01\x03\x02\x03\x03\x02\x01\x02\x02\x02\x03']
# Bad pipe message: %s [b'\xff9\x1f\xe8\xa2\xad,>yCLp#d\xe6\x06\xfeC\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc0', b".\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002"]

# %%
mask_dataFrame.to_excel('可借小於3的站點.xlsx')
